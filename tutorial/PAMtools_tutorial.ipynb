# %% [markdown]
# # Tutorial PAMtools

# %%
import importlib
import numpy as np
import pypam as pp
import matplotlib.pyplot as plt

# %%
importlib.reload(pp.pamplot)
# Out:
# <module 'pypam.pamplot' from '/mnt/c/Users/fsteffen/Github/PAMtools/pypam/pamplot.py'>

# %%
h = pp.pamplot.Hist2d.fromfile('data/P91_D23_A31_Atto550_647N.json')
# Out:
# <class 'matplotlib.patches.Polygon'>

# %%
h.plot2Dhist(style='contour', imgOffset=0)

#plt.savefig('test.png', format='png', dpi=1200, bbox_inches ='tight', transparent=True)
